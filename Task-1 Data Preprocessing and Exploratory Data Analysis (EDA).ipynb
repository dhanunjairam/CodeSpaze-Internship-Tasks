# %%
#Loading the dataset 
import pandas as pd 
data = pd.read_csv("/Users/ABC/Downloads/insurance.csv")

# %%
#Viewing the first 5 rows 
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Getting the info os the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Getting mean,std , etc 
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#getting the null value is there are any
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Getting the unique value in region column in Dataset
data.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
#Using matplotlib to plot the column called (sex)
import matplotlib.pyplot as plt
plt.hist(data['sex'])
plt.show()

# %%
#Transforming the categorial values into integers using LabelEncoder
from sklearn.preprocessing import LabelEncoder , MinMaxScaler
encoder = LabelEncoder()
data['sex']= encoder.fit_transform(data['sex'])
data['smoker']=encoder.fit_transform(data['smoker'])
data['region']=encoder.fit_transform(data['region'])

# %%
#Viewing data after LabelEncodeing
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
#Using seaborn to know the relation between all columns in dataset 
import seaborn as sns
import numpy as np
import matplotlib.cm as cm
f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
square=True, ax=ax,annot=True)
plt.show()

# %%
plt.scatter(data['bmi'],data['age'],)
plt.xlabel('bmi')
plt.ylabel('age')
plt.show()

# %%
# Plot two columns using seaborn (for example, 'age' vs 'charges')
sns.lineplot(x='age', y='charges', data=data, marker='o')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Age vs Charges')

# Display the plot
plt.show()

# %%
sns.set(style="ticks")

# Loading the dataset


# Show the results of a linear regression
sns.lmplot(x="bmi", y="charges", data=data)
